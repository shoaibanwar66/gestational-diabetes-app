# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats

import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression


import seaborn as sb

from scipy import stats

from pylab import rcParams

rcParams['figure.figsize'] = 8, 6
sb.set_style('whitegrid')

df = pd.read_csv('diabetes.csv')

df.head()

df.info()

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df['Glucose'] = df['Glucose'].replace(0,df['BMI'].mean())
df['BloodPressure'] = df['BloodPressure'].replace(0,df['BMI'].mean())
df['SkinThickness'] = df['SkinThickness'].replace(0,df['BMI'].mean())
df['Insulin'] = df['Insulin'].replace(0,df['BMI'].mean())
df['BMI'] = df['BMI'].replace(0,df['BMI'].mean())
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.102816      70.563464      29.992598   95.379198
# std       3.369578   31.280192      14.746220       8.886011  105.106957
# min       0.000000   31.992578      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      62.000000      25.000000   31.992578
# 50%       3.000000  117.000000      72.000000      31.992578   31.996289
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450805                  0.471876   33.240885    0.348958
# std      6.875374                  0.331329   11.760232    0.476951
# min     18.200000                  0.078000   21.000000    0.000000
# 25%     27.500000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# Pairplot 
sns.pairplot(data = dataset, hue = 'Outcome')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [5], line 2
#       1 # Pairplot
# ----> 2 sns.pairplot(data = dataset, hue = 'Outcome')
#       3 plt.show()
#
# NameError: name 'dataset' is not defined

# %%
sb.boxplot(data=df[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']], palette='hls')
# Out:
# <AxesSubplot:>

# %%
z_scores = stats.zscore(df)

abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores < 3).all(axis=1)
df_new = df[filtered_entries]
sb.boxplot(data=df_new[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']], palette='hls')
# Out:
# <AxesSubplot:>

# %%
print(df_new['Insulin'].quantile(0.10))
print(df_new['Insulin'].quantile(0.90))
df_new["Insulin"] = np.where(df_new["Insulin"] > 192.80, 192.80,df_new['Insulin'])
print(df_new['Insulin'].skew())
sb.boxplot(data=df_new[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']], palette='hls')
df_new.describe()
# Out:
# 31.992578124999977
# 192.80000000000007
# 0.93803816442777
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   723.000000  723.000000     723.000000     723.000000  723.000000
# mean      3.857538  119.622355      70.493427      29.650556   77.020340
# std       3.294906   30.657260      14.479528       8.286268   59.180623
# min       0.000000   31.992578      30.000000       7.000000   15.000000
# 25%       1.000000   99.000000      63.000000      25.000000   31.992578
# 50%       3.000000  115.000000      72.000000      31.992578   31.992578
# 75%       6.000000  138.000000      80.000000      32.000000  120.000000
# max      13.000000  199.000000     114.000000      54.000000  192.800000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  723.000000                723.000000  723.000000  723.000000
# mean    32.176256                  0.449281   32.972337    0.337483
# std      6.501435                  0.282582   11.313919    0.473178
# min     18.200000                  0.078000   21.000000    0.000000
# 25%     27.450000                  0.242000   24.000000    0.000000
# 50%     32.000000                  0.362000   29.000000    0.000000
# 75%     36.150000                  0.600500   40.000000    1.000000
# max     52.900000                  1.461000   68.000000    1.000000

# %%
# Having high BP vs high Glucose increase to have diabetes

# %%
sb.relplot(x = "Glucose", y = "BloodPressure", hue = "Outcome", data = df_new)

# %%
X = df_new.drop(['Outcome','SkinThickness', 'Insulin','BMI'], axis=1) # Features
y = df_new['Outcome'] # Lables

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

#train test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled,  y, test_size= 0.20,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)

y_predicted = lr.predict(X_test)

for i in range(len(y_predicted)):
    if y_predicted[i] < 0.5:
        y_predicted[i] = 0
    else:
        y_predicted[i] = 1

print("The first five predicted values are:")
print(y_predicted[0:5])
print("First five test values are:")
print(np.array(y_test[0:5]))
print("Coefficent of regression",lr.coef_)
print("Intercept of the regreesion line",lr.intercept_)
print("Accuracy of the model",lr.score(X_test, y_test))
# Out:
# The first five predicted values are:
# [0. 0. 0. 1. 0.]
# First five test values are:
# [0 0 0 0 0]
# Coefficent of regression [ 0.04562301  0.21004147 -0.01949303  0.08738432  0.03914126]
# Intercept of the regreesion line 0.33885515676771105
# Accuracy of the model 0.1915785805911705

# %%
y_pred = reg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

print("Accuracy_score is: {}".format(accuracy_score(y_test, y_pred))) 
print("Precision_score is: {}".format(precision_score(y_test, y_pred))) # Precision = TruePositives / (TruePositives + FalsePositives).
print("Recall_score is: {}".format(recall_score(y_test, y_pred))) # Recall = TruePositives / (TruePositives + FalseNegatives) 
                                                                # quantifies the number of positive class predictions made out of all positive examples in the dataset.
print("F1_score is: {}".format(f1_score(y_test, y_pred))) # provides a single score that balances both the concerns of precision and recall in one number.

#Precision: Appropriate when minimizing false positives is the focus.
#Recall: Appropriate when minimizing false negatives is the focus.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25948/1649781882.py in <module>
#       3 from sklearn.metrics import plot_confusion_matrix
#       4
# ----> 5 print("Accuracy_score is: {}".format(accuracy_score(y_test, y_pred)))
#       6 print("Precision_score is: {}".format(precision_score(y_test, y_pred))) # Precision = TruePositives / (TruePositives + FalsePositives).
#       7 print("Recall_score is: {}".format(recall_score(y_test, y_pred))) # Recall = TruePositives / (TruePositives + FalseNegatives)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     200
#     201     # Compute accuracy for each possible representation
# --> 202     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     203     check_consistent_length(y_true, y_pred, sample_weight)
#     204     if y_type.startswith('multilabel'):
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      90
#      91     if len(y_type) > 1:
# ---> 92         raise ValueError("Classification metrics can't handle a mix of {0} "
#      93                          "and {1} targets".format(type_true, type_pred))
#      94
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets

# %%
from sklearn import linear_model
import statsmodels.api as sm

x = df_new.drop(['Outcome','SkinThickness', 'Insulin','BMI', 'DiabetesPedigreeFunction','Age', 'Pregnancies'], axis=1) # Features
y = df_new['Outcome'] # Lables
regr = linear_model.LinearRegression()
regr.fit(x, y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# with statsmodels
x = sm.add_constant(x) # adding a constant
 
model = sm.OLS(y, x).fit()
predictions = model.predict(x) 
 
print_model = model.summary()

print(print_model)
# Out:
# Intercept:
#  -0.5837812108403267
# Coefficients:
#  [0.0071676  0.00090588]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Outcome   R-squared:                       0.222
# Model:                            OLS   Adj. R-squared:                  0.219
# Method:                 Least Squares   F-statistic:                     102.5
# Date:                Sun, 11 Sep 2022   Prob (F-statistic):           6.82e-40
# Time:                        11:48:09   Log-Likelihood:                -393.82
# No. Observations:                 723   AIC:                             793.6
# Df Residuals:                     720   BIC:                             807.4
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.5838      0.090     -6.472      0.000      -0.761      -0.407
# Glucose           0.0072      0.001     13.836      0.000       0.006       0.008
# BloodPressure     0.0009      0.001      0.826      0.409      -0.001       0.003
# ==============================================================================
# Omnibus:                       65.185   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.038
# Skew:                           0.566   Prob(JB):                     5.01e-12
# Kurtosis:                       2.333   Cond. No.                         823.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
plt.rc("figure", figsize=(16, 8))
plt.rc("font", size=14)
fig_bp = sm.graphics.plot_regress_exog(model, "BloodPressure")
fig_GLbp = sm.graphics.plot_regress_exog(model, "Glucose")
#fig.tight_layout(pad=1.0)
fig_bp.savefig("bp.png")
fig_GLbp.savefig("GLBP.png")

# %%
x = df_new.drop(['Outcome','SkinThickness', 'Insulin','BloodPressure',  'DiabetesPedigreeFunction','Age', 'Pregnancies'], axis=1) # Features
y = df_new['Outcome'] # Lables
regr = linear_model.LinearRegression()
regr.fit(x, y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# with statsmodels
x = sm.add_constant(x) # adding a constant
 
model = sm.OLS(y, x).fit()
predictions = model.predict(x) 
 
print_model = model.summary()

print(print_model)
# Out:
# Intercept:
#  -0.9610475146737564
# Coefficients:
#  [0.00656497 0.01595005]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Outcome   R-squared:                       0.267
# Model:                            OLS   Adj. R-squared:                  0.265
# Method:                 Least Squares   F-statistic:                     131.1
# Date:                Sun, 11 Sep 2022   Prob (F-statistic):           2.88e-49
# Time:                        12:10:41   Log-Likelihood:                -372.15
# No. Observations:                 723   AIC:                             750.3
# Df Residuals:                     720   BIC:                             764.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.9610      0.088    -10.879      0.000      -1.134      -0.788
# Glucose        0.0066      0.001     13.051      0.000       0.006       0.008
# BMI            0.0160      0.002      6.724      0.000       0.011       0.021
# ==============================================================================
# Omnibus:                       56.167   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.975
# Skew:                           0.490   Prob(JB):                     7.68e-10
# Kurtosis:                       2.341   Cond. No.                         746.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
plt.rc("figure", figsize=(16, 8))
plt.rc("font", size=14)
fig_bmi = sm.graphics.plot_regress_exog(model, "BMI")
fig_GLbmi = sm.graphics.plot_regress_exog(model, "Glucose")
#fig.tight_layout(pad=1.0)
fig_bmi.savefig("bmi.png")
fig_GLbmi.savefig("GLBMI.png")

# %%
import statistics
from scipy.stats import norm
# Plot between -10 and 10 with .001 steps.
x_axis = df['BMI']
x_axis = (x_axis-x_axis.min())/(x_axis.max()-x_axis.min())
# Calculating mean and standard deviation
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)
  
plt.plot(x_axis, norm.pdf(x_axis, mean, sd), '*')
plt.title('Normalized distribution for BMI')
plt.show()

# %%
x = df[['Outcome','BMI', 'Glucose']]
plt.figure(figsize = (12,12))
fig = sns.heatmap(data = x.corr(),annot = True, cmap = "YlGnBu")
#fig.set_size_inches(26, 26, forward=True)
plt.savefig("GBP.png",dpi=400)

# %%
fig = sns.heatmap(data = df.corr(),annot = True, cmap = "YlGnBu")

# %%
sb.relplot(x = "Glucose", y = "BMI", hue = "Outcome", data = df_new)
